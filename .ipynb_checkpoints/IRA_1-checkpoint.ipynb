# %%
import os
import tarfile
from six.moves import urllib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# Cargo el dataset

ira_dataset = pd.read_csv("IRA_1.csv", encoding = "ISO-8859-1")
# encoding = "ISO-8859-1" es lo mismo que latin 1

# %%
ira_dataset.shape
# Out:
# (2240, 12)

# %%
ira_dataset.index
# Out:
# RangeIndex(start=0, stop=2240, step=1)

# %%
ira_dataset.head() # Top five rows in the dataframe
# Out:
#                               D3.TRANSACCION CANAL_ATENCION  \
# 0                     Revisiones PeriÃ³dicas              _
# 1  Reclamaciones Presencial (resuelto/Final)     PRESENCIAL
# 2                    DaÃ±os EnergÃ­a Prepago              _
# 3                           DaÃ±os Acueducto              _
# 4         Peticiones Gas Oficinas (resuelto)     PRESENCIAL
#
#                                                CAUSA  \
# 0                                                  _
# 1  INCONFORMIDAD CON EL CONSUMO O PRODUCCION FACT...
# 2                                                  _
# 3                                                  _
# 4                                INFORMACION GENERAL
#
#                                          DESCRIPCION MOTIVO   MUNICIPIO  \
# 0                                                  _      _    MEDELLIN
# 1  INQUILINA RECLAMA POR CONSUMO ALTO DE ENERGIA ...      _  COPACABANA
# 2                                                  _      _           _
# 3                                                  _      _    MEDELLIN
# 4  Usuario en calidad de propietario solicita ori...      _       PE?OL
#
#   D0.SERVICIO  D2.PUNTO DE CONTACTO  Unnamed: 8   D5.LOCALIDAD  \
# 0         Gas   LÃ­nea de atenciÃ³n         NaN  Metropolitana
# 1    EnergÃ­a  Oficina de atenciÃ³n         NaN  Metropolitana
# 2    EnergÃ­a   LÃ­nea de atenciÃ³n         NaN       Regional
# 3   Acueducto   LÃ­nea de atenciÃ³n         NaN  Metropolitana
# 4         Gas  Oficina de atenciÃ³n         NaN       Regional
#
#   P3.ASPECTOS QUE LO SORPRENDIERON O QUE LE MOLESTARON     INCIDENTE CRITICO
# 0                                                  -      EXPERIENCIA NORMAL
# 1  PRIMERO ES MUY GRATO SABER QUE HAY FILAS PRIOR...    INCIDENTES NEGATIVOS
# 2                                                  _                       _
# 3  PORQUE TODO BIEN EN QUE ME RECIBIERON LA LLAMA...    INCIDENTES POSITIVOS
# 4  BUENA ATENCIÃN EN CUANTO A QUE ME  ATENDIERON...    INCIDENTES POSITIVOS

# %%
#Renombro columnas
ira_dataset = ira_dataset.rename(columns = {'P3.ASPECTOS QUE LO SORPRENDIERON O QUE LE MOLESTARON':'MENSAJE', 'INCIDENTE CRITICO':'SENTIMIENTO' })

# %%
ira_dataset.info() # Description of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 11 columns):
# D3.TRANSACCION          2240 non-null object
# CANAL_ATENCION          2240 non-null object
# CAUSA                   2240 non-null object
# DESCRIPCION             2240 non-null object
# MOTIVO                  2240 non-null object
# MUNICIPIO               2240 non-null object
# D0.SERVICIO             2240 non-null object
# D2.PUNTO DE CONTACTO    2240 non-null object
# D5.LOCALIDAD            2240 non-null object
# MENSAJE                 2240 non-null object
# SENTIMIENTO             2240 non-null object
# dtypes: object(11)
# memory usage: 192.6+ KB

# %%
# Esta balanceado el dataset?
print("Longitud del dataset", len(ira_dataset))
print()

print("Categorias Sentimientos Balanceada?: \n", ira_dataset.loc[:,'SENTIMIENTO'].value_counts())

#balanceado = tweet_dataset['polarity'].value_counts()
#print ("dataset balanceado? \n", balanceado)
# Out:
# Longitud del dataset 2240
#
# Categorias Sentimientos Balanceada?:
#  INCIDENTES POSITIVOS    1095
# EXPERIENCIA NORMAL       578
# INCIDENTES NEGATIVOS     479
# _                         88
# Name: SENTIMIENTO, dtype: int64

# %%
# Summary of the numerical attributes
ira_dataset.describe()
# Out:
#                             D3.TRANSACCION CANAL_ATENCION CAUSA DESCRIPCION  \
# count                                 2240           2240  2240        2240
# unique                                  24              9    44         766
# top     Peticiones Gas Oficinas (resuelto)              _     _           _
# freq                                    95           1433  1434        1449
#
#        MOTIVO MUNICIPIO D0.SERVICIO D2.PUNTO DE CONTACTO   D5.LOCALIDAD  \
# count    2240      2240        2240                 2240           2240
# unique      1       118           4                    5              2
# top         _  MEDELLIN    EnergÃ­a  LÃ­nea de atenciÃ³n  Metropolitana
# freq     2240      1066         719                  935           1734
#
#        MENSAJE           SENTIMIENTO
# count     2240                  2240
# unique    1575                     4
# top          -  INCIDENTES POSITIVOS
# freq       578                  1095

# %%
ira_dataset.count()
# Out:
# D3.TRANSACCION          2240
# CANAL_ATENCION          2240
# CAUSA                   2240
# DESCRIPCION             2240
# MOTIVO                  2240
# MUNICIPIO               2240
# D0.SERVICIO             2240
# D2.PUNTO DE CONTACTO    2240
# D5.LOCALIDAD            2240
# MENSAJE                 2240
# SENTIMIENTO             2240
# dtype: int64

# %%
#ira_dataset.drop('Unnamed: 8', axis = 1)
del ira_dataset['Unnamed: 8']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/ML/env/lib/python3.4/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 8'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-71bbfacae960> in <module>()
#       1 #ira_dataset.drop('Unnamed: 8', axis = 1)
# ----> 2 del ira_dataset['Unnamed: 8']
#
# ~/ML/env/lib/python3.4/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    2094             # there was no match, this call should raise the appropriate
#    2095             # exception:
# -> 2096             self._data.delete(key)
#    2097
#    2098         # delete from the caches
#
# ~/ML/env/lib/python3.4/site-packages/pandas/core/internals.py in delete(self, item)
#    3900         Delete selected item (items if non-unique) in-place.
#    3901         """
# -> 3902         indexer = self.items.get_loc(item)
#    3903
#    3904         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~/ML/env/lib/python3.4/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 8'

# %%
ira_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 11 columns):
# D3.TRANSACCION          2240 non-null object
# CANAL_ATENCION          2240 non-null object
# CAUSA                   2240 non-null object
# DESCRIPCION             2240 non-null object
# MOTIVO                  2240 non-null object
# MUNICIPIO               2240 non-null object
# D0.SERVICIO             2240 non-null object
# D2.PUNTO DE CONTACTO    2240 non-null object
# D5.LOCALIDAD            2240 non-null object
# MENSAJE                 2240 non-null object
# SENTIMIENTO             2240 non-null object
# dtypes: object(11)
# memory usage: 192.6+ KB

# %%
# usando la funcion head imprime los 5 primero registros con sentimiento positivo.
ira_dataset[ira_dataset['SENTIMIENTO'] == 'INCIDENTES POSITIVOS'].head()
# Out:
#                                D3.TRANSACCION CANAL_ATENCION  \
# 3                            DaÃ±os Acueducto              _
# 4          Peticiones Gas Oficinas (resuelto)     PRESENCIAL
# 9                      Revisiones PeriÃ³dicas              _
# 16  Reclamaciones Presencial (resuelto/Final)     PRESENCIAL
# 20                       Alternativas de Pago              _
#
#                                                 CAUSA  \
# 3                                                   _
# 4                                 INFORMACION GENERAL
# 9                                                   _
# 16  INCONFORMIDAD CON EL CONSUMO O PRODUCCION FACT...
# 20                                                  _
#
#                                           DESCRIPCION MOTIVO MUNICIPIO  \
# 3                                                   _      _  MEDELLIN
# 4   Usuario en calidad de propietario solicita ori...      _     PE?OL
# 9                                                   _      _  MEDELLIN
# 16  Usuaria en calidad de inquilina reclama por lo...      _     BELLO
# 20                                                  _      _  MEDELLIN
#
#    D0.SERVICIO  D2.PUNTO DE CONTACTO   D5.LOCALIDAD  \
# 3    Acueducto   LÃ­nea de atenciÃ³n  Metropolitana
# 4          Gas  Oficina de atenciÃ³n       Regional
# 9          Gas   LÃ­nea de atenciÃ³n  Metropolitana
# 16   Acueducto  Oficina de atenciÃ³n  Metropolitana
# 20   No aplica   LÃ­nea de atenciÃ³n  Metropolitana
#
#                                               MENSAJE           SENTIMIENTO
# 3   PORQUE TODO BIEN EN QUE ME RECIBIERON LA LLAMA...  INCIDENTES POSITIVOS
# 4   BUENA ATENCIÃN EN CUANTO A QUE ME  ATENDIERON...  INCIDENTES POSITIVOS
# 9   ME GUSTÃ MUCHO , NO TUVE NINGÃN PROBLEMA ME ...  INCIDENTES POSITIVOS
# 16  CUANDO LLEGUÃ A LA OFICINA ME ATENDIERON DE U...  INCIDENTES POSITIVOS
# 20  QUE EL ASESOR ME ATENDIÃ EN LA LÃNEA DE ATEN...  INCIDENTES POSITIVOS

# %%
# usando iloc accedamos al valor del segundo registro, de sentimiento positivo en el campo TEXTO.

print(ira_dataset[ira_dataset['SENTIMIENTO'] == 'INCIDENTES POSITIVOS'].MENSAJE.iloc[1])

print("Longitud Mensaje: ", len(ira_dataset[ira_dataset['SENTIMIENTO'] == 'INCIDENTES POSITIVOS'].MENSAJE.iloc[1]))




# usando iloc accedamos al valor del segundo registro, de sentimiento positivo en el campo TEXTO.

#print(tweet_dataset[tweet_dataset['polarity'] == 4].tweet_text.iloc[1])

#print("Longitud tweet: ", len(tweet_dataset[tweet_dataset['polarity'] == 4].tweet_text.iloc[1]))
# Out:
# BUENA ATENCIÃN EN CUANTO A QUE ME  ATENDIERON MUY RÃPIDO Y FUERON MUY ORDENADOS (NO DA MÃS INFORMACION)
# Longitud Mensaje:  106

# %%
# usando la funcion head imprime los 5 primero registros con sentimiento Neutro.
ira_dataset[ira_dataset['SENTIMIENTO'] == 'EXPERIENCIA NORMAL'].head()
# Out:
#                         D3.TRANSACCION CANAL_ATENCION  \
# 0               Revisiones PeriÃ³dicas              _
# 6   Quejas EnergÃ­a (incluido prepago)     TELEFONICO
# 10  Peticiones Gas Oficinas (resuelto)     PRESENCIAL
# 12                          DaÃ±os Gas              _
# 14              Revisiones PeriÃ³dicas              _
#
#                                   CAUSA  \
# 0                                     _
# 6            DEMORA EN ATENDER PETICION
# 10  SEPARACION TEMPORAL O PAGO DIRIGIDO
# 12                                    _
# 14                                    _
#
#                                           DESCRIPCION MOTIVO MUNICIPIO  \
# 0                                                   _      _  MEDELLIN
# 6   NOMBRE: NELSON CASTA?EDA\nCC: 8276620\nCEL: 30...      _    ITAGUI
# 10                     El usuario solicita separaci?n      _  MEDELLIN
# 12                                                  _      _  MEDELLIN
# 14                                                  _      _  MEDELLIN
#
#    D0.SERVICIO  D2.PUNTO DE CONTACTO   D5.LOCALIDAD MENSAJE  \
# 0          Gas   LÃ­nea de atenciÃ³n  Metropolitana       -
# 6     EnergÃ­a   LÃ­nea de atenciÃ³n  Metropolitana       -
# 10         Gas  Oficina de atenciÃ³n  Metropolitana       -
# 12         Gas   LÃ­nea de atenciÃ³n  Metropolitana       -
# 14         Gas   LÃ­nea de atenciÃ³n  Metropolitana       -
#
#            SENTIMIENTO
# 0   EXPERIENCIA NORMAL
# 6   EXPERIENCIA NORMAL
# 10  EXPERIENCIA NORMAL
# 12  EXPERIENCIA NORMAL
# 14  EXPERIENCIA NORMAL

# %%
# usando iloc accedamos al valor del segundo registro, de sentimiento Neutro en el campo TEXTO.

print(ira_dataset[ira_dataset['SENTIMIENTO'] == 'EXPERIENCIA NORMAL'].MENSAJE.iloc[1])

print("Longitud Mensaje: ", len(ira_dataset[ira_dataset['SENTIMIENTO'] == 'EXPERIENCIA NORMAL'].MENSAJE.iloc[1]))
# Out:
# -
# Longitud Mensaje:  1

# %%
# usando la funcion head imprime los 5 primero registros con sentimiento Negativo.
ira_dataset[ira_dataset['INCIDENTE CRITICO'] == 'INCIDENTES NEGATIVOS'].head()
# Out:
#                                D3.TRANSACCION CANAL_ATENCION  \
# 1   Reclamaciones Presencial (resuelto/Final)     PRESENCIAL
# 5                                  Quejas Gas     TELEFONICO
# 7             Quejas aguas (incluido prepago)     TELEFONICO
# 8                        Alternativas de Pago              _
# 11                                 Quejas Gas     TELEFONICO
#
#                                                 CAUSA  \
# 1   INCONFORMIDAD CON EL CONSUMO O PRODUCCION FACT...
# 5                              INCONFORMIDAD TRABAJOS
# 7             INCONFORMIDAD PUNTO DE VENTA YO RECAUDO
# 8                                                   _
# 11                   INCONFORMIDAD CON LA INFORMACION
#
#                                           DESCRIPCION MOTIVO      MUNICIPIO  \
# 1   INQUILINA RECLAMA POR CONSUMO ALTO DE ENERGIA ...      _     COPACABANA
# 5   Nombre: HERNAN DARIO ALVARES GARCES Cedula: 98...      _  SANTO DOMINGO
# 7   Nombre: Bernardo De Jes?s Meneses Restrepo\nCc...      _       MEDELLIN
# 8                                                   _      _       SABANETA
# 11  CLIENTE :EDISON MONSALVE CC :71723720TEL:30030...      _       MEDELLIN
#
#    D0.SERVICIO  D2.PUNTO DE CONTACTO   D5.LOCALIDAD  \
# 1     EnergÃ­a  Oficina de atenciÃ³n  Metropolitana
# 5          Gas   LÃ­nea de atenciÃ³n       Regional
# 7    Acueducto   LÃ­nea de atenciÃ³n  Metropolitana
# 8    No aplica   LÃ­nea de atenciÃ³n  Metropolitana
# 11         Gas   LÃ­nea de atenciÃ³n  Metropolitana
#
#    P3.ASPECTOS QUE LO SORPRENDIERON O QUE LE MOLESTARON     INCIDENTE CRITICO
# 1   PRIMERO ES MUY GRATO SABER QUE HAY FILAS PRIOR...    INCIDENTES NEGATIVOS
# 5   LA DEMORA EN EL ARREGLO Y ESTUVE  SIN SERVICIO...    INCIDENTES NEGATIVOS
# 7   PUES LO QUE ME MOLESTO ES QUE ELLOS LE DICEN A...    INCIDENTES NEGATIVOS
# 8   NO ME PRESTARON  EL SERVICIO  EN CUANTO A QUE ...    INCIDENTES NEGATIVOS
# 11  NO ME RESOLVIERON EL PROBLEMA NO DA MÃS INFOR...    INCIDENTES NEGATIVOS

# %%
# usando iloc accedamos al valor del segundo registro, de sentimiento Neutro en el campo TEXTO.

print(ira_dataset[ira_dataset['SENTIMIENTO'] == 'INCIDENTES NEGATIVOS'].MENSAJE.iloc[1])

print("Longitud Mensaje: ", len(ira_dataset[ira_dataset['SENTIMIENTO'] == 'INCIDENTES NEGATIVOS'].MENSAJE.iloc[1]))
# Out:
# LA DEMORA EN EL ARREGLO Y ESTUVE  SIN SERVICIO  POR VARIOS DÃAS Y NO HABÃA RESPUESTA NI POR PARTE DE EPM NI DEL CONTRATISTA ME PONÃAN DE UN LADO A OTRO
# Longitud Mensaje:  154

# %%
# valida campos null
print(ira_dataset.isnull()) # Validar esto
# Out:
#       D3.TRANSACCION  CANAL_ATENCION  CAUSA  DESCRIPCION  MOTIVO  MUNICIPIO  \
# 0              False           False  False        False   False      False
# 1              False           False  False        False   False      False
# 2              False           False  False        False   False      False
# 3              False           False  False        False   False      False
# 4              False           False  False        False   False      False
# 5              False           False  False        False   False      False
# 6              False           False  False        False   False      False
# 7              False           False  False        False   False      False
# 8              False           False  False        False   False      False
# 9              False           False  False        False   False      False
# 10             False           False  False        False   False      False
# 11             False           False  False        False   False      False
# 12             False           False  False        False   False      False
# 13             False           False  False        False   False      False
# 14             False           False  False        False   False      False
# 15             False           False  False        False   False      False
# 16             False           False  False        False   False      False
# 17             False           False  False        False   False      False
# 18             False           False  False        False   False      False
# 19             False           False  False        False   False      False
# 20             False           False  False        False   False      False
# 21             False           False  False        False   False      False
# 22             False           False  False        False   False      False
# 23             False           False  False        False   False      False
# 24             False           False  False        False   False      False
# 25             False           False  False        False   False      False
# 26             False           False  False        False   False      False
# 27             False           False  False        False   False      False
# 28             False           False  False        False   False      False
# 29             False           False  False        False   False      False
# ...              ...             ...    ...          ...     ...        ...
# 2210           False           False  False        False   False      False
# 2211           False           False  False        False   False      False
# 2212           False           False  False        False   False      False
# 2213           False           False  False        False   False      False
# 2214           False           False  False        False   False      False
# 2215           False           False  False        False   False      False
# 2216           False           False  False        False   False      False
# 2217           False           False  False        False   False      False
# 2218           False           False  False        False   False      False
# 2219           False           False  False        False   False      False
# 2220           False           False  False        False   False      False
# 2221           False           False  False        False   False      False
# 2222           False           False  False        False   False      False
# 2223           False           False  False        False   False      False
# 2224           False           False  False        False   False      False
# 2225           False           False  False        False   False      False
# 2226           False           False  False        False   False      False
# 2227           False           False  False        False   False      False
# 2228           False           False  False        False   False      False
# 2229           False           False  False        False   False      False
# 2230           False           False  False        False   False      False
# 2231           False           False  False        False   False      False
# 2232           False           False  False        False   False      False
# 2233           False           False  False        False   False      False
# 2234           False           False  False        False   False      False
# 2235           False           False  False        False   False      False
# 2236           False           False  False        False   False      False
# 2237           False           False  False        False   False      False
# 2238           False           False  False        False   False      False
# 2239           False           False  False        False   False      False
#
#       D0.SERVICIO  D2.PUNTO DE CONTACTO  D5.LOCALIDAD  MENSAJE  SENTIMIENTO
# 0           False                 False         False    False        False
# 1           False                 False         False    False        False
# 2           False                 False         False    False        False
# 3           False                 False         False    False        False
# 4           False                 False         False    False        False
# 5           False                 False         False    False        False
# 6           False                 False         False    False        False
# 7           False                 False         False    False        False
# 8           False                 False         False    False        False
# 9           False                 False         False    False        False
# 10          False                 False         False    False        False
# 11          False                 False         False    False        False
# 12          False                 False         False    False        False
# 13          False                 False         False    False        False
# 14          False                 False         False    False        False
# 15          False                 False         False    False        False
# 16          False                 False         False    False        False
# 17          False                 False         False    False        False
# 18          False                 False         False    False        False
# 19          False                 False         False    False        False
# 20          False                 False         False    False        False
# 21          False                 False         False    False        False
# 22          False                 False         False    False        False
# 23          False                 False         False    False        False
# 24          False                 False         False    False        False
# 25          False                 False         False    False        False
# 26          False                 False         False    False        False
# 27          False                 False         False    False        False
# 28          False                 False         False    False        False
# 29          False                 False         False    False        False
# ...           ...                   ...           ...      ...          ...
# 2210        False                 False         False    False        False
# 2211        False                 False         False    False        False
# 2212        False                 False         False    False        False
# 2213        False                 False         False    False        False
# 2214        False                 False         False    False        False
# 2215        False                 False         False    False        False
# 2216        False                 False         False    False        False
# 2217        False                 False         False    False        False
# 2218        False                 False         False    False        False
# 2219        False                 False         False    False        False
# 2220        False                 False         False    False        False
# 2221        False                 False         False    False        False
# 2222        False                 False         False    False        False
# 2223        False                 False         False    False        False
# 2224        False                 False         False    False        False
# 2225        False                 False         False    False        False
# 2226        False                 False         False    False        False
# 2227        False                 False         False    False        False
# 2228        False                 False         False    False        False
# 2229        False                 False         False    False        False
# 2230        False                 False         False    False        False
# 2231        False                 False         False    False        False
# 2232        False                 False         False    False        False
# 2233        False                 False         False    False        False
# 2234        False                 False         False    False        False
# 2235        False                 False         False    False        False
# 2236        False                 False         False    False        False
# 2237        False                 False         False    False        False
# 2238        False                 False         False    False        False
# 2239        False                 False         False    False        False
#
# [2240 rows x 11 columns]

# %%
# valida si hay filas con nan y en caso de que si usa el metodo .dropna(), ajusta el parametro inplace en True.
#print(np.isnan(ira_dataset))

#x = x[numpy.logical_not(numpy.isnan(x))]
#print(ira_dataset['Site Fill'].value_counts(dropna=False))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-04b3faf660f5> in <module>()
#       1 # valida si hay filas con nan y en caso de que si usa el metodo .dropna(), ajusta el parametro inplace en True.
# ----> 2 print(np.isnan(ira_dataset))
#       3
#       4 #x = x[numpy.logical_not(numpy.isnan(x))]
#       5 #print(df['Site Fill'].value_counts(dropna=False))
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
# Cuales son los descriptores que nos aportan informacion para el analisis de sentimientos?, cuales no?
# usando el metodo drop() de los DataFrame, elimina los campos que no son necesarios para el analisis 
# de sentimientos, recuerda ajustar un atributo en 1 y otro en True.
#ira_dataset.columns 
ira_dataset.drop(['D3.TRANSACCION','CANAL_ATENCION','CAUSA','DESCRIPCION', 'MOTIVO', 'MUNICIPIO',
'D0.SERVICIO', 'D2.PUNTO DE CONTACTO', 'D5.LOCALIDAD'], axis = 1, inplace = True)
# axis = 1 elimina valores de la columna

# %%
ira_dataset.head()
# Out:
#                                              MENSAJE           SENTIMIENTO
# 0                                                  -    EXPERIENCIA NORMAL
# 1  PRIMERO ES MUY GRATO SABER QUE HAY FILAS PRIOR...  INCIDENTES NEGATIVOS
# 2                                                  _                     _
# 3  PORQUE TODO BIEN EN QUE ME RECIBIERON LA LLAMA...  INCIDENTES POSITIVOS
# 4  BUENA ATENCIÃN EN CUANTO A QUE ME  ATENDIERON...  INCIDENTES POSITIVOS
